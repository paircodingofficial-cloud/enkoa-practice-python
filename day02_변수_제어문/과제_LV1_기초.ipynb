# %% [markdown]
# # 📝 파이썬 기초 과제 LV1(기초) — 변수·제어문
#
# > 오늘 배운 개념을 **하나씩** 확인하는 문제입니다. 교안을 옆에 두고 풀어도 좋아요!
#
# ## 푸는 방법
# - `# 여기에 코드를 작성하세요` 라고 적힌 **답안 셀**에 코드를 채웁니다.
# - `# [자가채점]` 셀이 있는 문제는, 답을 쓴 뒤 그 셀을 실행해 **에러가 없으면 통과**입니다.
# - `input()` 문제는 정해진 값을 넣어 **예시 입출력**과 같은지 눈으로 비교하세요.
# - 막히면 각 문제의 `힌트` 를 펼쳐 보세요.
#
# ## 다루는 개념
# 변수 · f-string · 형변환 · 사칙연산 · `if` / `elif` / `else` · `while` · `for` + `range` · `break` · `continue` · 문자열 순회
#
# ---

# %% [markdown]
# ## 1. 나를 소개합니다
#
# **배경**: 새 학기 첫날, 자기소개 카드를 만들려고 합니다. **이름·나이·취미**를 각각 변수에 담고, f-string 한 줄로 소개 문장을 출력하세요.
#
# **요구사항**:
# - 변수 3개: `name`(문자열), `age`(정수), `hobby`(문자열)
# - f-string 으로 한 줄 출력
#
# **예시**
# ```
# 저는 김파이이고, 25살이며, 취미는 등산입니다.
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 이름·나이·취미를 각각 변수에 담고, f-string 한 줄에 세 값을 끼워 출력한다.
#
# 세부구현:
# 1. 값 준비
#    1-1. 이름·취미는 문자열(따옴표)로, 나이는 정수로 각각 name, age, hobby에 저장한다.
# 2. 출력
#    2-1. f-string 안에 세 변수를 넣어 한 문장으로 출력한다.
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 2. 두 수의 사칙연산
#
# **배경**: 간단한 계산기입니다. 두 정수를 입력받아 **덧셈·뺄셈·곱셈·나눗셈** 결과를 각각 한 줄씩 출력하세요.
#
# **요구사항**:
# - `int(input())` 으로 두 수 `a`, `b` 입력
# - `a+b`, `a-b`, `a*b`, `a/b` 를 각각 출력
#
# **예시**
# ```
# 첫 번째 수: 10
# 두 번째 수: 3
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.3333333333333335
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 두 수를 정수로 입력받아, 네 가지 연산 결과를 각각 한 줄씩 출력한다.
#
# 세부구현:
# 1. 입력
#    1-1. input()으로 받은 값을 정수로 바꿔 a, b에 저장한다.
# 2. 계산·출력
#    2-1. 더하기·빼기·곱하기·나누기 결과를 각각 f-string으로 한 줄씩 출력한다.
#    2-2. 나누기(/)의 결과는 항상 실수라는 점에 유의한다.
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 3. 섭씨 → 화씨 변환기
#
# **배경**: 해외 날씨 앱을 만드는 중입니다. 섭씨 온도를 입력받아 화씨로 변환해 출력하세요.
#
# > 공식: **화씨 = 섭씨 × 9 / 5 + 32**
#
# **예시**
# ```
# 섭씨 온도: 25
# 섭씨 25도는 화씨 77.0도 입니다.
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 섭씨 값을 입력받아 변환 공식을 그대로 적용해 화씨를 구한다.
#
# 세부구현:
# 1. 입력
#    1-1. 섭씨 온도를 정수로 입력받아 celsius에 저장한다.
# 2. 변환·출력
#    2-1. 화씨 = 섭씨 × 9 ÷ 5 + 32 로 계산해 fahrenheit에 담는다. (곱셈·나눗셈이 덧셈보다 먼저 계산됨)
#    2-2. 결과를 문장으로 출력한다.
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 4. 짝수 · 홀수 판별기
#
# **배경**: 정수를 입력받아 짝수인지 홀수인지 판별하세요. (첫 조건문 문제!)
#
#
# **예시**
# ```
# 숫자: 7
# 7은(는) 홀수입니다.
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 2로 나눈 나머지로 짝수/홀수를 가른다.
#
# 세부구현:
# 1. 입력
#    1-1. 정수 하나를 입력받아 number에 저장한다.
# 2. 판별·출력
#    2-1. number를 2로 나눈 나머지가 0이면 짝수, 아니면 홀수라고 출력한다. (if/else)
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 5. 놀이공원 요금 안내
#
# **배경**: 나이에 따라 입장료가 다릅니다. 나이를 입력받아 구분과 요금을 출력하세요.
#
# | 구분 | 나이 | 요금 |
# |---|---|---|
# | 미취학 | 0~7 | 무료 |
# | 어린이 | 8~13 | 10,000원 |
# | 청소년 | 14~19 | 20,000원 |
# | 성인 | 20~64 | 30,000원 |
# | 경로 | 65 이상 | 무료 |
#
# **예시**
# ```
# 나이: 15
# 청소년: 20,000원
# ```
# ```
# 나이: 5
# 미취학: 무료
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 나이를 좁은 구간(작은 경계)부터 차례로 검사하는 elif 사다리로 요금을 정한다.
#
# 세부구현:
# 1. 입력
#    1-1. 나이를 정수로 입력받아 age에 저장한다.
# 2. 구간 판별 (위에서 아래로)
#    2-1. 7 이하면 미취학(무료).
#    2-2. 13 이하면 어린이(10,000원).
#    2-3. 19 이하면 청소년(20,000원).
#    2-4. 64 이하면 성인(30,000원).
#    2-5. 그 밖(65 이상)이면 경로(무료).
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 6. 세 수 중 최댓값 (max 없이!)
#
# **배경**: 세 개의 수 `a`, `b`, `c` 가 아래처럼 미리 주어집니다. **`max()` 함수 없이** `if` 문만으로
# 가장 큰 값을 찾아 변수 **`result`** 에 저장하세요.
#
# ```python
# a = 17
# b = 42
# c = 33
# ```
#
# **요구사항**:
# - `result` 에 세 수 중 가장 큰 값을 담는다 (`if` 만 사용)
# - `print(result)` 로 확인
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - "지금까지 본 가장 큰 값"을 한 변수에 계속 갱신하는 최댓값 추적 패턴을 쓴다.
#
# 세부구현:
# 1. 초기화
#    1-1. 첫 후보로 result를 a로 둔다.
# 2. 비교·갱신
#    2-1. b가 result보다 크면 result를 b로 바꾼다.
#    2-2. c가 result보다 크면 result를 c로 바꾼다.
# 3. 결과
#    3-1. result를 출력한다.
# ```
#
# </details>

# %%
# [제공 코드] — 아래 세 값이 미리 주어집니다
a = 17
b = 42
c = 33

# %%
# 여기에 코드를 작성하세요

# %%
# [자가채점]
assert result == 42, f"최댓값은 42여야 합니다 (현재 {result})."
print("✅ 자가채점 통과!")

# %% [markdown]
# ## 7. 1부터 100까지의 합 (while)
#
# **배경**: `while` 반복문으로 1부터 100까지 모든 정수를 더한 합을 구해 변수 **`result`** 에 저장하세요.
# (`sum()` 은 아직 쓰지 않습니다 — 직접 누적!)
#
# **요구사항**:
# - `while` 사용, `result` 에 1~100 합 저장
# - 정답은 `5050`
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 1부터 100까지 하나씩 더해 나가는 누적 패턴을 while로 구현한다.
#
# 세부구현:
# 1. 초기화
#    1-1. 합을 담을 result를 0으로, 세는 값 i를 1로 둔다.
# 2. 반복 (i가 100 이하인 동안)
#    2-1. result에 i를 더한다.
#    2-2. i를 1 늘린다. (안 늘리면 무한 반복!)
# 3. 결과
#    3-1. result를 출력한다. (정답 5050)
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %%
# [자가채점]
assert result == 5050, f"1~100 합은 5050이어야 합니다 (현재 {result})."
print("✅ 자가채점 통과!")

# %% [markdown]
# ## 8. 구구단 한 단 출력 (for)
#
# **배경**: 원하는 단을 입력받아 그 단의 구구단(1~9곱)을 출력하세요.
#
# **예시**
# ```
# 몇 단? 3
# 3 x 1 = 3
# 3 x 2 = 6
# ...
# 3 x 9 = 27
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 곱하는 수만 1~9로 바꿔가며 반복 출력한다.
#
# 세부구현:
# 1. 입력
#    1-1. 출력할 단을 정수로 입력받아 dan에 저장한다.
# 2. 반복 출력
#    2-1. 1부터 9까지 반복하며 dan × i 값을 "dan x i = 값" 형태로 출력한다.
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 9. 카운트다운 (break)
#
# **배경**: 10부터 1씩 줄여가며 출력하다가, **3이 되는 순간 멈추세요**(`break`). 멈출 때 `"3에서 중단!"`을 출력합니다.
#
# **예시**
# ```
# 10 9 8 7 6 5 4 3에서 중단!
# ```
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 10에서 1까지 거꾸로 세다가, 특정 값에서 반복을 완전히 중단(break)한다.
#
# 세부구현:
# 1. 반복 (10부터 1까지, 1씩 감소)
#    1-1. 현재 값이 3이면 "3에서 중단!"을 출력하고 반복을 멈춘다(break).
#    1-2. 그 전에는 현재 값을 출력한다.
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %% [markdown]
# ## 10. 3의 배수만 (continue)
#
# **배경**: 1부터 30까지 중 **3의 배수만** 출력하되, `continue` 를 사용하세요. 그리고 3의 배수의 **개수**를
# 변수 **`result`** 에 저장하세요.
#
# **요구사항**:
# - `continue` 로 3의 배수가 아닌 수는 건너뛰기
# - 3의 배수 개수를 `result` 에 저장 (정답 `10`)
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 3의 배수가 아닌 수는 건너뛰고(continue), 배수만 출력하며 개수를 센다.
#
# 세부구현:
# 1. 초기화
#    1-1. 개수 result를 0으로 둔다.
# 2. 반복 (1부터 30까지)
#    2-1. 3으로 나눈 나머지가 0이 아니면 건너뛴다(continue).
#    2-2. 남은(3의 배수) 값을 출력하고 result를 1 늘린다.
# 3. 결과
#    3-1. result를 출력한다. (정답 10)
# ```
#
# </details>

# %%
# 여기에 코드를 작성하세요

# %%
# [자가채점]
assert result == 10, f"1~30 의 3의 배수는 10개여야 합니다 (현재 {result})."
print("✅ 자가채점 통과!")

# %% [markdown]
# ## 11. 단어의 모음 개수 세기
#
# **배경**: 문자열을 `for` 로 **한 글자씩 순회**하며, 그 안에 든 **모음(a, e, i, o, u)** 의 개수를 세어 봅니다.
# 아래 주어진 `word` 의 모음 개수를 변수 **`vowel_count`** 에 저장하세요.
#
# ```python
# word = "programming"     # 모음: o, a, i → 3개
# ```
#
# **요구사항**:
# - `for ch in word:` 로 글자를 하나씩 꺼낸다
# - `if ch in "aeiou":` 로 모음인지 판별해 개수를 누적
# - 모음 개수를 `vowel_count` 에 저장 (정답 `3`)
#
# <details><summary>힌트</summary>
#
# ```text
# 접근방법:
# - 문자열을 한 글자씩 훑으며, 모음이면 개수를 하나씩 늘리는 누적 패턴을 쓴다.
#
# 세부구현:
# 1. 초기화
#    1-1. 개수 vowel_count를 0으로 둔다.
# 2. 반복 (word의 글자를 하나씩)
#    2-1. 글자가 모음(a, e, i, o, u) 중 하나면 vowel_count를 1 늘린다.
# 3. 결과
#    3-1. vowel_count를 출력한다. (정답 3)
# ```
#
# </details>

# %%
# [제공 코드] — 아래 단어가 미리 주어집니다
word = "programming"

# %%
# 여기에 코드를 작성하세요

# %%
# [자가채점]
assert vowel_count == 3, f"'programming' 의 모음은 3개여야 합니다 (현재 {vowel_count})."
print("✅ 자가채점 통과!")

# %% [markdown]
# ---
#
# ## 수고했어요!
#
# 11문제를 모두 풀었다면 오늘 배운 기초 개념을 잘 익힌 거예요.
# 자신 있으면 **`과제_LV2_응용.ipynb`** 로 넘어가 개념을 조합해 봅시다!
#
# > 정답과 해설은 수업이 끝난 뒤 강사가 공유합니다.
