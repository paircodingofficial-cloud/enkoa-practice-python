# %% [markdown]
# ## 유튜브 영상 검색

# %% [markdown]
# ### 0. 환경 변수 로드

# %%
import os
from dotenv import load_dotenv

load_dotenv() # 환경 변수 불러오기 (.env)

YOUTUBE_API_KEY = os.getenv("YOUTUBE_API_KEY")

# %% [markdown]
# ### 1.검색 리스트 API를 토대로 영상 검색

# %%
import requests
import pandas as pd
from pprint import pprint


service_url = 'https://www.googleapis.com/youtube/v3/search'

# %%
# 필요한 데이터 저장

# %% [markdown]
# ### 2. 영상 상세 정보 조회
# - 영상 1개에 대해 조회수, 좋아요 수, 코멘트 수 등 상세 정보 조회

# %%
service_url = 'https://www.googleapis.com/youtube/v3/videos'

# %%
# 영상 상세 정보 추출

# %% [markdown]
# ### 3. 영상 검색 정보와 상세 정보 데이터 병합 및 저장
