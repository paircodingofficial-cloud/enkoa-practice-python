# %% [markdown]
# ## 홀리스 카페 주소의 위도, 경도 얻기

# %% [markdown]
# ### TODO
#
# - [] 0. 카카오 맵 API KEY 발급
# - [] 1. 환경 변수 로드
# - [] 2. API 호출 테스트
#     - 주소를 넣고 위도 경도 얻기
# - [] 3. API 함수 생성
#     - 주소를 파라미터로 받고 위도, 경도 반환
# - [] 3. 할리스 카페 파일 로드 (data/hollys_stores.csv)
# - [] 4. 각 주소를 반복문으로 순회
#     - 각 주소의 위도, 경도 얻기
#     - 기존 정보에 새로운 키로 위도, 경도 할당
# - [] 5. data/hollys_stores_위도_경도.csv 파일로 데이터 저장
