# %% [markdown]
# # 네이버 연관검색어 수집하기

# %% [markdown]
# ## 1. API 요청에 필요한 기본 정보 설정
# - 네이버 API에 요청을 보내기 위한 기본 정보를 설정

# %% [markdown]
# ## 2. API 요청 보내기
# - 설정한 정보를 바탕으로 API에 요청

# %% [markdown]
# ## 3. 연관검색어 추출하기
# - 응답 데이터에서 연관검색어만 추출

# %% [markdown]
# ## 4. 재사용성을 위한 함수화
