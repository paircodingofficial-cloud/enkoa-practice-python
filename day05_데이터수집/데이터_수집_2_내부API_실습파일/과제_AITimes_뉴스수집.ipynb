# %% [markdown]
# ### TODO
#
# - [] 0. 내부 API 탐색
#     - 네트워크 분석 (페이지 전환 혹은 기사 더보기 등 동작 수행)
#
# - [] 1. 내부 API 호출 테스트
# - [] 2. API 함수 생성
# - [] 3. 1~10페이지 분량의 데이터 수집
# - [] 4. 데이터 저장
# - [] 5. data/ai_times_{오늘날짜}_{페이지수}.csv 파일 이름으로 데이터 저장
